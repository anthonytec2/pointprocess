# %%
import h5py
import hdf5plugin

# %%
f = h5py.File("/new-pool/ev_list/spinner/spin.h5")

# %%
f["events"][100, 0]

# %%
idx = 1900
img = np.zeros((32, 32))
ev_seq = f["events"][idx, 0]
p_seq = ev_seq[ev_seq[:, 2] == 1]
x_idx = (p_seq[:, 0] % 32).astype(np.uint16)
y_idx = (p_seq[:, 1] % 32).astype(np.uint16)
img[x_idx, y_idx] = p_seq[:, 3]
plt.imshow(img)

# %%
plt.plot(ev_seq[:, 3])

# %%
plt.plot
